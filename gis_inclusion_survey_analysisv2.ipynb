# %% [markdown]
# # GIS Inclusion Survey Analysis
#
# grouped indices, descriptive statistics, reliability checks, pre/post comparisons, demographic summaries, open-ended response themes and visuals

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 120)

DATA_PATH = Path('gis_survey_cleaned.xlsx')
OUT_DIR = Path('gis_survey_outputs')
FIG_DIR = OUT_DIR / 'figures'
TABLE_DIR = OUT_DIR / 'tables'
EXCEL_PATH = TABLE_DIR / 'survey_analysis_tables.xlsx'

FIG_DIR.mkdir(parents=True, exist_ok=True)
TABLE_DIR.mkdir(parents=True, exist_ok=True)


def save_table_to_excel(table, sheet_name):
    with pd.ExcelWriter(EXCEL_PATH, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
        table.to_excel(writer, sheet_name=sheet_name, index=False)

# %% [markdown]
# ## data cleaning

# %%
df_raw = pd.read_excel(DATA_PATH)

#date
df = df_raw.copy()
df['StartDate'] = pd.to_datetime(df['StartDate'], errors='coerce')
df['EndDate'] = pd.to_datetime(df['EndDate'], errors='coerce')
df = df[df['StartDate'].notna()].copy()

df['survey_month'] = df['StartDate'].dt.month
df['period'] = np.where(df['survey_month'] == 6, 'Before',
                        np.where(df['survey_month'] == 12, 'After', 'Other'))

df = df[df['period'].isin(['Before', 'After'])].copy()

len(df_raw)
len(df)
display(df['period'].value_counts().rename_axis('period').reset_index(name='n'))
# Out:
# C:\Users\snigd\AppData\Local\Temp\ipykernel_36392\3421016971.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['StartDate'] = pd.to_datetime(df['StartDate'], errors='coerce')
# C:\Users\snigd\AppData\Local\Temp\ipykernel_36392\3421016971.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['EndDate'] = pd.to_datetime(df['EndDate'], errors='coerce')
#    period   n
# 0   After  21
# 1  Before   5

# %% [markdown]
# ## groups for indices

# %%
indices = {
    'Curriculum Representation': ['Q2.2', 'Q2.3', 'Q2.4', 'Q2.5'],
    'Inclusive Case Studies': ['Q3.2', 'Q3.3', 'Q3.5', 'Q3.6', 'Q3.7'],
    'Inclusive Course Materials': ['Q4.2', 'Q4.3', 'Q4.4', 'Q4.5'],
    'Inclusive Teaching Activities': ['Q5.3', 'Q5.4', 'Q5.5', 'Q5.6'],
    'Responsible Spatial Practice': ['Q2.7', 'Q5.7']
}

demographic_cols = ['Q1.3', 'Q1.4', 'Q1.5', 'Q1.6']
technical_cols = ['Q1.7', 'Q1.8']
awareness_cols = ['Q1.9', 'Q1.10']
open_ended_cols = ['Q6.2', 'Q6.3', 'Q6.4']

for name, cols in indices.items():
    print(f'{name}: {cols}')
# Out:
# Curriculum Representation: ['Q2.2', 'Q2.3', 'Q2.4', 'Q2.5']
# Inclusive Case Studies: ['Q3.2', 'Q3.3', 'Q3.5', 'Q3.6', 'Q3.7']
# Inclusive Course Materials: ['Q4.2', 'Q4.3', 'Q4.4', 'Q4.5']
# Inclusive Teaching Activities: ['Q5.3', 'Q5.4', 'Q5.5', 'Q5.6']
# Responsible Spatial Practice: ['Q2.7', 'Q5.7']

# %% [markdown]
# ## survey responses to numeric scores
#
# converted to a 1–5 scale -- higher values mean stronger agreement, better representation or stronger inclusion

# %%
score_maps = {
    'before_after_gis': {
        'Very less': 1,
        'Less': 2,
        'Moderate': 3,
        'Very well': 4,
        'Extreamly well': 5,
        'Extremely well': 5,
        'Somewhat improved': 4,
        'Significantly improved': 5,
    },
    'curriculum_items': {
        'No': 1,
        'Very less': 2,
        'Less': 3,
        'Maybe': 3,
        'Moderate': 4,
        'Very well': 5,
    },
    'how_well_items': {
        'Not well at all': 1,
        'Slightly well': 2,
        'Moderately well': 3,
        'Very well': 4,
        'Extreamly well': 5,
        'Extremely well': 5,
    }
}

curriculum_scale_cols = [
    'Q2.2', 'Q2.3', 'Q2.4', 'Q2.5', 'Q2.7',
    'Q3.2', 'Q3.3', 'Q3.5', 'Q3.6', 'Q3.7',
    'Q4.2', 'Q4.3', 'Q4.4', 'Q4.5'
]

how_well_scale_cols = ['Q5.3', 'Q5.4', 'Q5.5', 'Q5.6', 'Q5.7']
background_scale_cols = technical_cols + awareness_cols

num = df.copy()

for col in curriculum_scale_cols:
    num[col + '_score'] = num[col].map(score_maps['curriculum_items'])

for col in how_well_scale_cols:
    num[col + '_score'] = num[col].map(score_maps['how_well_items'])

for col in background_scale_cols:
    num[col + '_score'] = num[col].map(score_maps['before_after_gis'])

cols_to_score = sorted(set(sum(indices.values(), []) + technical_cols + awareness_cols))
for col in cols_to_score:
    missing = num.loc[num[col].notna() & num[col + '_score'].isna(), col].unique()
    if len(missing) > 0:
        print(f'Unmapped values in {col}: {missing}')

# %% [markdown]
# ## index scores

# %%
for index_name, cols in indices.items():
    score_cols = [c + '_score' for c in cols]
    num[index_name] = num[score_cols].mean(axis=1)

index_names = list(indices.keys())

num['Overall Inclusive GIS Curriculum Score'] = num[index_names].mean(axis=1)

display(num[['period'] + index_names + ['Overall Inclusive GIS Curriculum Score']].head())
# Out:
#    period  Curriculum Representation  Inclusive Case Studies  \
# 1  Before                       5.00                     5.0
# 2  Before                       4.25                     4.2
# 3  Before                       3.75                     3.4
# 4  Before                       5.00                     4.6
# 5  Before                       2.75                     2.8
#
#    Inclusive Course Materials  Inclusive Teaching Activities  \
# 1                        5.00                           5.00
# 2                        4.00                           4.25
# 3                        2.25                           4.50
# 4                        4.75                           4.50
# 5                        2.50                           3.50
#
#    Responsible Spatial Practice  Overall Inclusive GIS Curriculum Score
# 1                           4.0                                    4.80
# 2                           4.0                                    4.14
# 3                           4.0                                    3.58
# 4                           4.0                                    4.57
# 5                           4.5                                    3.21

# %% [markdown]
# ## participant characteristics
#
# for introducing the survey (??)

# %%
def count_percent_table(data, col, label):
    out = data[col].value_counts(dropna=False).reset_index()
    out.columns = [label, 'n']
    out['percent'] = (out['n'] / len(data) * 100).round(1)
    return out

participant_tables = {}
for col, label in zip(demographic_cols, ['Academic background', 'Gender', 'Program year', 'Student status']):
    participant_tables[label] = count_percent_table(df, col, label)
    display(participant_tables[label])

for label, table in participant_tables.items():
    safe = label.lower().replace(' ', '_')
    table.to_csv(TABLE_DIR / f'{safe}.csv', index=False)
# Out:
#   Academic background   n  percent
# 0         Engineering  10     38.5
# 1               Other  10     38.5
# 2      Urban Planning   3     11.5
# 3      Social Science   3     11.5
#    Gender   n  percent
# 0    Male  14     53.8
# 1  Female  12     46.2
#   Program year   n  percent
# 0     1st year  19     73.1
# 1     2nd year   6     23.1
# 2        Other   1      3.8
#   Student status   n  percent
# 0  International  18     69.2
# 1       Domestic   8     30.8

# %% [markdown]
# ## cronbach's alpha
#
# to check whether the questions in each index behave like they are measuring the same construct

# %%
def cronbach_alpha(dataframe):
    """Calculate Cronbach's alpha for a set of numeric survey items."""
    x = dataframe.dropna()
    if x.shape[0] < 2 or x.shape[1] < 2:
        return np.nan
    item_variances = x.var(axis=0, ddof=1)
    total_variance = x.sum(axis=1).var(ddof=1)
    n_items = x.shape[1]
    if total_variance == 0:
        return np.nan
    return (n_items / (n_items - 1)) * (1 - item_variances.sum() / total_variance)

alpha_rows = []
for index_name, cols in indices.items():
    score_cols = [c + '_score' for c in cols]
    alpha_rows.append({
        'Index': index_name,
        'Questions': ', '.join(cols),
        'Number of items': len(cols),
        "Cronbach's alpha": round(cronbach_alpha(num[score_cols]), 3)
    })

alpha_table = pd.DataFrame(alpha_rows)
display(alpha_table)
alpha_table.to_csv(TABLE_DIR / 'cronbach_alpha_by_index.csv', index=False)
# Out:
#                            Index                     Questions  \
# 0      Curriculum Representation        Q2.2, Q2.3, Q2.4, Q2.5
# 1         Inclusive Case Studies  Q3.2, Q3.3, Q3.5, Q3.6, Q3.7
# 2     Inclusive Course Materials        Q4.2, Q4.3, Q4.4, Q4.5
# 3  Inclusive Teaching Activities        Q5.3, Q5.4, Q5.5, Q5.6
# 4   Responsible Spatial Practice                    Q2.7, Q5.7
#
#    Number of items  Cronbach's alpha
# 0                4             0.850
# 1                5             0.814
# 2                4             0.776
# 3                4             0.773
# 4                2             0.505

# %% [markdown]
# ## descriptive statistics (for each index)
#
# before/after mean, standard deviation and sample size for each index

# %%
desc_rows = []
for index_name in index_names + ['Overall Inclusive GIS Curriculum Score']:
    for period in ['Before', 'After']:
        values = num.loc[num['period'] == period, index_name].dropna()
        desc_rows.append({
            'Index': index_name,
            'Period': period,
            'n': len(values),
            'Mean': round(values.mean(), 3),
            'SD': round(values.std(ddof=1), 3),
            'Median': round(values.median(), 3),
            'Min': round(values.min(), 3),
            'Max': round(values.max(), 3)
        })

desc_table = pd.DataFrame(desc_rows)
display(desc_table)
save_table_to_excel(desc_table, 'descriptive_statistics_by_index')
# Out:
#                                      Index  Period   n   Mean     SD  Median  \
# 0                Curriculum Representation  Before   5  4.150  0.945    4.25
# 1                Curriculum Representation   After  21  3.929  0.771    4.00
# 2                   Inclusive Case Studies  Before   5  4.000  0.894    4.20
# 3                   Inclusive Case Studies   After  21  3.790  0.685    4.00
# 4               Inclusive Course Materials  Before   5  3.700  1.267    4.00
# 5               Inclusive Course Materials   After  21  3.714  0.614    3.75
# 6            Inclusive Teaching Activities  Before   5  4.350  0.548    4.50
# 7            Inclusive Teaching Activities   After  21  3.536  0.634    3.50
# 8             Responsible Spatial Practice  Before   5  4.100  0.224    4.00
# 9             Responsible Spatial Practice   After  21  4.048  0.835    4.50
# 10  Overall Inclusive GIS Curriculum Score  Before   5  4.060  0.665    4.14
# 11  Overall Inclusive GIS Curriculum Score   After  21  3.803  0.591    3.84
#
#      Min   Max
# 0   2.75  5.00
# 1   2.25  5.00
# 2   2.80  5.00
# 3   2.40  4.80
# 4   2.25  5.00
# 5   2.50  4.75
# 6   3.50  5.00
# 7   2.00  4.75
# 8   4.00  4.50
# 9   2.50  5.00
# 10  3.21  4.80
# 11  2.73  4.66
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %% [markdown]
# ## statistical comparisons
#
# since they are diff cohorts, used the Mann–Whitney U test. Also reported Cohen's d as a simple effect size for the mean difference

# %%
from scipy.stats import mannwhitneyu

# %%
def cohens_d(x, y):
    # Cohen's d for two independent groups
    x = pd.Series(x).dropna()
    y = pd.Series(y).dropna()
    nx, ny = len(x), len(y)
    if nx < 2 or ny < 2:
        return np.nan
    pooled_sd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / (nx + ny - 2))
    if pooled_sd == 0:
        return np.nan
    return (y.mean() - x.mean()) / pooled_sd

comparison_rows = []
for index_name in index_names + ['Overall Inclusive GIS Curriculum Score']:
    before = num.loc[num['period'] == 'Before', index_name].dropna()
    after = num.loc[num['period'] == 'After', index_name].dropna()
    
    if len(before) > 0 and len(after) > 0:
        u_stat, p_value = mannwhitneyu(before, after, alternative='two-sided')
        d = cohens_d(before, after)
        comparison_rows.append({
            'Index': index_name,
            'Before Mean': round(before.mean(), 3),
            'After Mean': round(after.mean(), 3),
            'Difference': round(after.mean() - before.mean(), 3),
            'Percent Change': round(((after.mean() - before.mean()) / before.mean()) * 100, 1) if before.mean() != 0 else np.nan,
            'Mann-Whitney U': round(u_stat, 3),
            'p-value': round(p_value, 4),
            "Cohen's d": round(d, 3)
        })

comparison_table = pd.DataFrame(comparison_rows)
display(comparison_table)
save_table_to_excel(comparison_table, 'pre_post_comparisons')
# Out:
#                                     Index  Before Mean  After Mean  \
# 0               Curriculum Representation         4.15       3.929
# 1                  Inclusive Case Studies         4.00       3.790
# 2              Inclusive Course Materials         3.70       3.714
# 3           Inclusive Teaching Activities         4.35       3.536
# 4            Responsible Spatial Practice         4.10       4.048
# 5  Overall Inclusive GIS Curriculum Score         4.06       3.803
#
#    Difference  Percent Change  Mann-Whitney U  p-value  Cohen's d
# 0      -0.221            -5.3            61.5   0.5773     -0.276
# 1      -0.210            -5.2            61.5   0.5784     -0.289
# 2       0.014             0.4            56.0   0.8443      0.019
# 3      -0.814           -18.7            90.5   0.0138     -1.313
# 4      -0.052            -1.3            45.5   0.6623     -0.068
# 5      -0.257            -6.3            67.0   0.3621     -0.425
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %% [markdown]
# ## grouped index comparison

# %%
plot_data = desc_table[desc_table['Index'].isin(index_names)].pivot(index='Index', columns='Period', values='Mean')
plot_data = plot_data[['Before', 'After']]

ax = plot_data.plot(kind='bar', figsize=(11, 6))
ax.set_title('Pre/Post Comparison of Inclusive GIS Curriculum Indices')
ax.set_ylabel('Mean score, 1–5 scale')
ax.set_xlabel('')
ax.set_ylim(0, 5)
plt.xticks(rotation=30, ha='right')
plt.legend(title='Period')
plt.tight_layout()

plt.savefig(FIG_DIR / 'index_comparison_grouped_bar.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## heatmap of index means

# %%
heat = plot_data.copy()

fig, ax = plt.subplots(figsize=(6, 4))
im = ax.imshow(heat.values, aspect='auto')

ax.set_xticks(np.arange(len(heat.columns)))
ax.set_xticklabels(heat.columns)
ax.set_yticks(np.arange(len(heat.index)))
ax.set_yticklabels(heat.index)
ax.set_title('Mean Index Scores Before and After Redesign')

for i in range(heat.shape[0]):
    for j in range(heat.shape[1]):
        ax.text(j, i, f'{heat.iloc[i, j]:.2f}', ha='center', va='center')

fig.colorbar(im, ax=ax, label='Mean score')
plt.tight_layout()
plt.savefig(FIG_DIR / 'index_mean_heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## overall inclusive curriculum score

# %%
overall = desc_table[desc_table['Index'] == 'Overall Inclusive GIS Curriculum Score'].set_index('Period').loc[['Before', 'After']]

ax = overall['Mean'].plot(kind='bar', figsize=(6, 5))
ax.set_title('Overall Inclusive GIS Curriculum Score')
ax.set_ylabel('Mean score, 1–5 scale')
ax.set_xlabel('')
ax.set_ylim(0, 5)
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig(FIG_DIR / 'overall_inclusive_curriculum_score.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Technical learning before and after the course
#
# to emphasize that technical learning has not been affected by the curriculum change

# %%
tech_summary = []
for col, label in [('Q1.7', 'GIS background before course'), ('Q1.8', 'GIS background after course')]:
    score_col = col + '_score'
    for period in ['Before', 'After']:
        values = num.loc[num['period'] == period, score_col].dropna()
        tech_summary.append({
            'Measure': label,
            'Period': period,
            'n': len(values),
            'Mean': round(values.mean(), 3),
            'SD': round(values.std(ddof=1), 3)
        })

tech_table = pd.DataFrame(tech_summary)
display(tech_table)
save_table_to_excel(tech_table, 'technical_learning_summary')

tech_plot = tech_table.pivot(index='Measure', columns='Period', values='Mean')[['Before', 'After']]
ax = tech_plot.plot(kind='bar', figsize=(8, 5))
ax.set_title('Technical GIS Background and Learning')
ax.set_ylabel('Mean score')
ax.set_xlabel('')
ax.set_ylim(0, 5)
plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.savefig(FIG_DIR / 'technical_learning_bar.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                         Measure  Period   n   Mean     SD
# 0  GIS background before course  Before   5  2.000  1.000
# 1  GIS background before course   After  21  1.714  1.007
# 2   GIS background after course  Before   5  5.000  0.000
# 3   GIS background after course   After  21  4.714  0.463
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %% [markdown]
# ## demographic comparisons
#
# exploratory (if required for building the context)

# %%
status_summary = num.groupby(['period', 'Q1.6'])['Overall Inclusive GIS Curriculum Score'].agg(['count', 'mean', 'std']).reset_index()
status_summary['mean'] = status_summary['mean'].round(3)
status_summary['std'] = status_summary['std'].round(3)
display(status_summary)
save_table_to_excel(status_summary, 'overall_score_by_student_status')

background_summary = num.groupby(['period', 'Q1.3'])['Overall Inclusive GIS Curriculum Score'].agg(['count', 'mean', 'std']).reset_index()
background_summary['mean'] = background_summary['mean'].round(3)
background_summary['std'] = background_summary['std'].round(3)
display(background_summary)
save_table_to_excel(background_summary, 'overall_score_by_academic_background')
# Out:
#    period           Q1.6  count   mean    std
# 0   After       Domestic      7  3.791  0.548
# 1   After  International     14  3.809  0.632
# 2  Before       Domestic      1  3.580    NaN
# 3  Before  International      4  4.180  0.702
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
#    period            Q1.3  count   mean    std
# 0   After     Engineering      9  3.836  0.611
# 1   After           Other      7  3.810  0.368
# 2   After  Social Science      3  3.983  0.972
# 3   After  Urban Planning      2  3.365  0.898
# 4  Before     Engineering      1  4.800    NaN
# 5  Before           Other      3  3.787  0.703
# 6  Before  Urban Planning      1  4.140    NaN
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %% [markdown]
# ## question-level means
#
# to refer back

# %%
question_labels = {
    'Q2.2': 'Curriculum represents diverse perspectives',
    'Q2.3': 'Balanced gender diversity',
    'Q2.4': 'Balanced diverse demographics',
    'Q2.5': 'Balanced geographic regions',
    'Q2.7': 'Understanding social/cultural issues',
    'Q3.2': 'Case studies from diverse groups',
    'Q3.3': 'Case studies on gender diversity',
    'Q3.5': 'Case studies on diverse geographies',
    'Q3.6': 'Case studies on diverse demographics',
    'Q3.7': 'Case studies on social/cultural issues',
    'Q4.2': 'Materials on diverse groups',
    'Q4.3': 'Materials on gender diversity',
    'Q4.4': 'Materials on diverse geographies',
    'Q4.5': 'Materials on diverse demographics',
    'Q5.3': 'Diverse perspectives in lectures',
    'Q5.4': 'Diverse perspectives in demos',
    'Q5.5': 'Diverse perspectives in homework',
    'Q5.6': 'Diverse perspectives in final projects',
    'Q5.7': 'Connect GIS skills to societal problems'
}

question_rows = []
for q, label in question_labels.items():
    score_col = q + '_score'
    for period in ['Before', 'After']:
        values = num.loc[num['period'] == period, score_col].dropna()
        question_rows.append({
            'Question': q,
            'Label': label,
            'Period': period,
            'n': len(values),
            'Mean': round(values.mean(), 3),
            'SD': round(values.std(ddof=1), 3)
        })

question_table = pd.DataFrame(question_rows)
display(question_table)
save_table_to_excel(question_table, 'question_level_means')
# Out:
#    Question                                       Label  Period   n   Mean  \
# 0      Q2.2  Curriculum represents diverse perspectives  Before   5  4.000
# 1      Q2.2  Curriculum represents diverse perspectives   After  21  4.048
# 2      Q2.3                   Balanced gender diversity  Before   5  3.800
# 3      Q2.3                   Balanced gender diversity   After  21  3.619
# 4      Q2.4               Balanced diverse demographics  Before   5  4.600
# 5      Q2.4               Balanced diverse demographics   After  21  4.095
# 6      Q2.5                 Balanced geographic regions  Before   5  4.200
# 7      Q2.5                 Balanced geographic regions   After  21  3.952
# 8      Q2.7        Understanding social/cultural issues  Before   5  3.800
# 9      Q2.7        Understanding social/cultural issues   After  21  4.000
# 10     Q3.2            Case studies from diverse groups  Before   5  4.000
# 11     Q3.2            Case studies from diverse groups   After  21  3.524
# 12     Q3.3            Case studies on gender diversity  Before   5  3.400
# 13     Q3.3            Case studies on gender diversity   After  21  3.190
# 14     Q3.5         Case studies on diverse geographies  Before   5  4.600
# 15     Q3.5         Case studies on diverse geographies   After  21  4.095
# 16     Q3.6        Case studies on diverse demographics  Before   5  3.800
# 17     Q3.6        Case studies on diverse demographics   After  21  4.048
# 18     Q3.7      Case studies on social/cultural issues  Before   5  4.200
# 19     Q3.7      Case studies on social/cultural issues   After  21  4.095
# 20     Q4.2                 Materials on diverse groups  Before   5  3.600
# 21     Q4.2                 Materials on diverse groups   After  21  3.524
# 22     Q4.3               Materials on gender diversity  Before   5  2.800
# 23     Q4.3               Materials on gender diversity   After  21  3.143
# 24     Q4.4            Materials on diverse geographies  Before   5  4.600
# 25     Q4.4            Materials on diverse geographies   After  21  4.095
# 26     Q4.5           Materials on diverse demographics  Before   5  3.800
# 27     Q4.5           Materials on diverse demographics   After  21  4.095
# 28     Q5.3            Diverse perspectives in lectures  Before   5  3.800
# 29     Q5.3            Diverse perspectives in lectures   After  21  3.286
# 30     Q5.4               Diverse perspectives in demos  Before   5  4.400
# 31     Q5.4               Diverse perspectives in demos   After  21  3.381
# 32     Q5.5            Diverse perspectives in homework  Before   5  4.600
# 33     Q5.5            Diverse perspectives in homework   After  21  3.571
# 34     Q5.6      Diverse perspectives in final projects  Before   5  4.600
# 35     Q5.6      Diverse perspectives in final projects   After  21  3.905
# 36     Q5.7     Connect GIS skills to societal problems  Before   5  4.400
# 37     Q5.7     Connect GIS skills to societal problems   After  21  4.095
#
#        SD
# 0   1.000
# 1   0.921
# 2   1.095
# 3   1.071
# 4   0.894
# 5   0.700
# 6   1.304
# 7   1.024
# 8   0.447
# 9   1.095
# 10  1.225
# 11  0.928
# 12  1.140
# 13  0.814
# 14  0.548
# 15  0.831
# 16  1.304
# 17  1.117
# 18  0.837
# 19  0.944
# 20  1.673
# 21  0.981
# 22  1.789
# 23  0.910
# 24  0.548
# 25  0.768
# 26  1.304
# 27  0.768
# 28  0.837
# 29  0.845
# 30  0.894
# 31  0.805
# 32  0.548
# 33  0.926
# 34  0.548
# 35  0.889
# 36  0.548
# 37  0.889
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %% [markdown]
# ## Likert distribution plots

# %%
ordered_responses = ['No', 'Very less', 'Less', 'Maybe', 'Moderate', 'Not well at all',
                     'Slightly well', 'Moderately well', 'Very well', 'Extreamly well', 'Extremely well']

selected_questions = ['Q2.2', 'Q2.5', 'Q3.2', 'Q4.2', 'Q5.5', 'Q5.7']

for q in selected_questions:
    dist = (
        df.groupby('period')[q]
        .value_counts(normalize=True)
        .rename('percent')
        .reset_index()
    )
    dist['percent'] = dist['percent'] * 100
    dist_pivot = dist.pivot(index=q, columns='period', values='percent').fillna(0)
    
    dist_pivot = dist_pivot.loc[[r for r in ordered_responses if r in dist_pivot.index]]
    
    ax = dist_pivot.plot(kind='barh', figsize=(8, 5))
    ax.set_title(f'Response Distribution: {q} - {question_labels.get(q, q)}')
    ax.set_xlabel('Percent of responses')
    ax.set_ylabel('')
    plt.tight_layout()
    plt.savefig(FIG_DIR / f'likert_distribution_{q}.png', dpi=300, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ## Qualitative categorization

# %%
for col in open_ended_cols:
    print('' + col)
    display(df[['period', col]].dropna())
# Out:
# Q6.2
#     period  \
# 1   Before
# 2   Before
# 5   Before
# 6    After
# 7    After
# 9    After
# 10   After
# 11   After
# 12   After
# 14   After
# 17   After
# 18   After
# 19   After
# 20   After
# 23   After
# 26   After
#
#                                                                                                                        Q6.2
# 1                                                                                                                        no
# 2                                            some interesting and actionable GIS application to tackle real-world challenge
# 5   Most students in class has no background in GIS, thus its natural for the professor to demonstrate the tools and dem...
# 6   When you said 'diverse' does that mean diverse in American context? I kind of confused. But I think it covers East a...
# 7                                 Most of the data we worked with was based in the US, and tended to be very urban-focused.
# 9                                            More examples and datasets from diverse regions, not only U.S.-based cities.\n
# 10                                                            The current GIS curriculum is sufficient for its inclusivity.
# 11                Maybe Different countries in the activities would be helpful in addressing issues in different countries.
# 12  I think the curriculum could include more examples that highlight diverse social and environmental issues faced by d...
# 14  Using data from diverse industries/looking at case studies of how employers use GIS. Making maps of regions outside ...
# 17  I honestly think you did a great job! I enjoyed using GIS to explore data around the US, but I wonder if you could i...
# 18  Id have loved to map some other country to learn about other borders, or see how different countries represented dis...
# 19                                                                  The assignment contents can try include more diversity.
# 20                                                                     gender inclusivity and other countries, other cities
# 23  The examples and case studies in this course could represent a diverse range of communities from other countries as ...
# 26                                                                                    Diverse tool usage such as using QGIS
# Q6.3
#     period  \
# 1   Before
# 5   Before
# 6    After
# 7    After
# 9    After
# 10   After
# 11   After
# 12   After
# 14   After
# 16   After
# 17   After
# 18   After
# 19   After
# 20   After
# 22   After
# 23   After
# 25   After
# 26   After
#
#                                                                                                                        Q6.3
# 1                                                                                                                        no
# 5   A lot of the students in the GIS class are international students, who lack their knowledge of American history and ...
# 6    I want to say to explore more from outside the US, but the data is really limited (I have tried it for my country lol)
# 7   Having more rural communities, and countries beyond the US would be very useful; including a focus on alternative me...
# 9   Rural areas, Global South communities, and low-income neighborhoods that face environmental and infrastructure chall...
# 10                                                                   Maybe some foreign countries such as France or Canada.
# 11                                                                     International students or international communities.
# 12  It would be great to see more case studies from underrepresented regions like Southeast Asia, Africa, and Indigenous...
# 14                                                                  Women, youth, low-income neighborhoods, other countries
# 16  I think looking at more international cities would be helpful, though I understand that is difficult with language b...
# 17                                 Sunbelt region, or maybe parts of the country that lean more conservative or Republican?
# 18                                               Pacific islands. How do those differ in mapping? what about water mapping?
# 19                                                                                         all groups under marginalization
# 20                                                                                 women's issues, underdeveloped countries
# 22                                          Maybe use datasets other than cities based in US. Some global datasets as well.
# 23  I think it would be helpful to include at least one project at a country-wide or larger regional scale (e.g., U.S. o...
# 25                                                             Maybe more about the Spanish and African communities in NYC.
# 26                                                                                                     Developing countries
# Q6.4
#     period  \
# 1   Before
# 6    After
# 9    After
# 10   After
# 11   After
# 12   After
# 18   After
# 20   After
# 23   After
# 26   After
#
#                                                                                                                        Q6.4
# 1                                                                                                                        no
# 6                                                                                                                         -
# 9   Open-source global datasets (e.g., UN SDG data, WorldPop, OpenStreetMap) and case studies focused on underserved reg...
# 10                                                       Datasets from public transit such as MTA, MBTA, SEPTA, WMATA, etc.
# 11                                                      Datasets of different countries that are available in the internet.
# 12  I would love to see more open-source global datasets, like Humanitarian Data Exchange or UN spatial data, added to g...
# 18                                                                                                                       no
# 20                                                                        stop and frisk, mayor's office to ENDGBV datasets
# 23  I would really like to work more with raster data and real-world imagery, such as drone photos or satellite images. ...
# 26                                                                                        Datasets from Google earth engine

# %%
# Simple keyword dictionary for first-pass thematic coding
theme_keywords = {
    'Global South / international contexts': ['global south', 'international', 'india', 'africa', 'latin', 'asia', 'south asia', 'developing'],
    'Rural communities': ['rural'],
    'Indigenous communities': ['indigenous', 'native', 'tribal', 'first nations'],
    'Accessibility / disability': ['accessibility', 'disability', 'disabled', 'ada'],
    'Environmental justice / climate': ['environmental', 'climate', 'flood', 'pollution', 'green space'],
    'Gender': ['gender', 'female', 'women'],
    'Transportation': ['transportation', 'transit', 'subway', 'mobility'],
    'Data / datasets': ['data', 'dataset', 'datasets'],
    'Readings / resources': ['reading', 'readings', 'resource', 'resources', 'paper', 'article'],
    'Community engagement': ['community', 'participatory', 'engagement']
}

open_text = df[open_ended_cols].fillna('').agg(' '.join, axis=1).str.lower()

theme_rows = []
for theme, keywords in theme_keywords.items():
    for period in ['Before', 'After']:
        texts = open_text[df['period'] == period]
        count = texts.apply(lambda x: any(k in x for k in keywords)).sum()
        theme_rows.append({
            'Theme': theme,
            'Period': period,
            'Count': int(count),
            'Percent': round(count / len(texts) * 100, 1) if len(texts) > 0 else np.nan
        })

theme_table = pd.DataFrame(theme_rows)
display(theme_table)
save_table_to_excel(theme_table, 'open_ended_theme_counts_first_pass')

# Plot theme counts
theme_plot = theme_table.pivot(index='Theme', columns='Period', values='Count').fillna(0)
theme_plot = theme_plot[['Before', 'After']]
ax = theme_plot.plot(kind='barh', figsize=(10, 7))
ax.set_title('First-Pass Themes in Open-Ended Responses')
ax.set_xlabel('Number of responses mentioning theme')
ax.set_ylabel('')
plt.tight_layout()
plt.savefig(FIG_DIR / 'open_ended_theme_counts.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                                     Theme  Period  Count  Percent
# 0   Global South / international contexts  Before      1     20.0
# 1   Global South / international contexts   After      7     33.3
# 2                       Rural communities  Before      0      0.0
# 3                       Rural communities   After      3     14.3
# 4                  Indigenous communities  Before      0      0.0
# 5                  Indigenous communities   After      2      9.5
# 6              Accessibility / disability  Before      0      0.0
# 7              Accessibility / disability   After      1      4.8
# 8         Environmental justice / climate  Before      0      0.0
# 9         Environmental justice / climate   After      2      9.5
# 10                                 Gender  Before      0      0.0
# 11                                 Gender   After      2      9.5
# 12                         Transportation  Before      0      0.0
# 13                         Transportation   After      1      4.8
# 14                        Data / datasets  Before      1     20.0
# 15                        Data / datasets   After     12     57.1
# 16                   Readings / resources  Before      0      0.0
# 17                   Readings / resources   After      0      0.0
# 18                   Community engagement  Before      0      0.0
# 19                   Community engagement   After      1      4.8
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")

# %%
analysis_path = TABLE_DIR / 'analysis_ready_survey_with_indices.csv'
num.to_csv(analysis_path, index=False)
save_table_to_excel(num, 'analysis_ready_survey_with_indices')
# Out:
# c:\Users\snigd\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
